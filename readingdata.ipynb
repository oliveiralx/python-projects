# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

time = np.linspace(0,0.01,360)

# %%
t1 = pd.read_csv('datas\d_rpm30.txt', delimiter=",")

data_ang = t1['Ângulo']
data_vel = t1['Velocidade']

# %%
#plt.plot(time, data_ang)
plt.plot(time, data_vel)
plt.grid(linestyle='--')
plt.show()

# %%
plt.plot(time, data_ang)
plt.grid(True)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
t1 = pd.read_csv('DataBase\DADOS\RPM73\ANG-VEL_SEM-TIMESTAMP.txt', delimiter=",")

data_ang = t1['Ângulo']
data_vel = t1['Velocidade']

# %%
time = np.linspace(0,0.01,300)

# %%
plt.plot(time, data_vel)
plt.plot(time, data_ang)

plt.subplot(2, 1, 1)
plt.plot(time, data_vel, 'green')
plt.title('BNO055 Values')
plt.ylabel('Velocity (RPM)')
plt.grid(linestyle='--')

plt.subplot(2, 1, 2)
plt.plot(time, data_ang)
plt.xlabel('time (s)')
plt.ylabel('Angle')
plt.grid(linestyle='--')
plt.show()

# %%
plt.plot(time, data_ang)
plt.grid(True)
plt.show()

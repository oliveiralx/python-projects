# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
t1 = pd.read_csv('teste2.txt', delimiter=",")
t1
# Out:
#       Ângulo  Velocidade
# 0        357        1.10
# 1        357        1.10
# 2        357        2.10
# 3        357        2.10
# 4        357        2.10
# ...      ...         ...
# 2532     338       -3.51
# 2533     342       -6.08
# 2534     342       -6.08
# 2535     342       -6.08
# 2536     349      -13.58
#
# [2537 rows x 2 columns]

# %%
t1 = pd.read_csv('teste2.txt', delimiter=",")

data_ang = t1['Ângulo']
data_vel = t1['Velocidade'] * -1
#data_time = t1['Tempo']

# %%
dt = 1
data_time = np.arange(0, 2537, dt)

# %%
plt.plot(data_time, data_vel)
plt.plot(data_time, data_ang)
#plot angle and velocity with 5 minutes from start

plt.subplot(2, 1, 1)
plt.plot(data_time, data_vel, 'green')
plt.title('BNO055 Values')
plt.ylabel('Velocity (RPM)')
plt.grid(linestyle='--')

plt.subplot(2, 1, 2)
plt.plot(data_time, data_ang)
plt.xlabel('time (s)')
plt.ylabel('Angle')
plt.grid(linestyle='--')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
t1 = pd.read_csv('ensaio3.txt', delimiter=",")
t1
# Out:
#       angle  Velocidade   Tempo
# 0       135       -1.61   11.65
# 1       135       -2.16   11.69
# 2       135       -2.16   11.69
# 3       136       -2.10   11.72
# 4       136       -2.10   11.72
# ...     ...         ...     ...
# 6688      0        0.53    0.53
# 6689    321      -37.04  131.57
# 6690    321      -37.04  131.57
# 6691    321      -37.04  131.60
# 6692    321      -37.04  131.60
#
# [6693 rows x 3 columns]

# %%
t1 = pd.read_csv('ensaio1.txt', delimiter=",")

data_ang = t1['angle'] 
data_vel = t1['Velocidade'] * -1
#data_time = t1['Tempo']
data_time = np.linspace(0,1,6668)

# %%
time = np.linspace(0,1,866)

# %%
plt.plot(data_time, data_vel)
plt.plot(data_time, data_ang)
#plot angle and velocity with 5 minutes from start

plt.subplot(2, 1, 1)
plt.plot(data_time, data_vel, 'green')
plt.title('BNO055 Values')
plt.ylabel('Velocity (RPM)')
plt.grid(linestyle='--')

plt.subplot(2, 1, 2)
plt.plot(data_time, data_ang)
plt.xlabel('time (s)')
plt.ylabel('Angle')
plt.grid(linestyle='--')
plt.show()

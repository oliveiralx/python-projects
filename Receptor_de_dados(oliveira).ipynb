# %%
import serial.tools.list_ports
from time import time

ports = serial.tools.list_ports.comports()
serialInst = serial.Serial()

portList = []

for onePort in ports:
    portList.append(str(onePort))
    print(str(onePort))

val = input("Select Port: COM")

for x in range(0, len(portList)):
    if portList[x].startswith("COM" + str(val)):
        portVar = "COM" + str(val)
        print('\nSelected Port:')
        print(portList[x])
        print(f'Colecting data from {portVar}...\n')

serialInst.baudrate = 9600
serialInst.port = portVar
serialInst.open()


tempo_esperado = 10



list_1 = []; list_2 = []; list_3 = []; eixo = ['eixo x','eixo y', 'eixo z']


start = time()


while (time()-start <= tempo_esperado):
    if serialInst.in_waiting:
        packet = serialInst.readline()
        print(packet.decode('utf').rstrip('\n'))
        list_1.append(packet)
# Out:
# COM4 - Silicon Labs CP210x USB to UART Bridge (COM4)
# COM1 - Porta de comunicação (COM1)
#
# Selected Port:
# COM4 - Silicon Labs CP210x USB to UART Bridge (COM4)
# Colecting data from COM4...
#
# Access Denied
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40
# 150,33.40

# %%
# list of names
list_1

# open file in write mode
with open(r'teste.txt', 'w') as fp:
    for item in list_1:
        # write each item on a new line
        fp.write(item.decode('utf'))
    print('Done')
# Out:
# Done

# %%
b = b'1234'
print(b.decode('utf'))
print(list_1.decode('utf'))
# Out:
# 1234
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Usuario [ Não Apagar ]\Nova pasta (2)\Gits\python-projects\Receptor_de_dados(oliveira).ipynb Célula: 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Usuario%20%5B%20N%C3%A3o%20Apagar%20%5D/Nova%20pasta%20%282%29/Gits/python-projects/Receptor_de_dados%28oliveira%29.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> b = b'1234'
#       <a href='vscode-notebook-cell:/d%3A/Usuario%20%5B%20N%C3%A3o%20Apagar%20%5D/Nova%20pasta%20%282%29/Gits/python-projects/Receptor_de_dados%28oliveira%29.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> print(b.decode('utf'))
# ----> <a href='vscode-notebook-cell:/d%3A/Usuario%20%5B%20N%C3%A3o%20Apagar%20%5D/Nova%20pasta%20%282%29/Gits/python-projects/Receptor_de_dados%28oliveira%29.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> list_1.decode('utf')
#
# AttributeError: 'list' object has no attribute 'decode'

# %%
import serial.tools.list_ports
from time import time

ports = serial.tools.list_ports.comports()
serialInst = serial.Serial()

portList = []

for onePort in ports:
    portList.append(str(onePort))
    print(str(onePort))

val = input("Select Port: COM")

for x in range(0, len(portList)):
    if portList[x].startswith("COM" + str(val)):
        portVar = "COM" + str(val)
        print('\nSelected Port:')
        print(portList[x])
        print(f'Colecting data from {portVar}...\n')
    else:
        print('Access Denied')

serialInst.baudrate = 9600
serialInst.port = portVar
serialInst.open()


tempo_esperado = 10



list_1 = []; list_2 = []; list_3 = []; eixo = ['eixo x','eixo y', 'eixo z']

# 1135133 = 201 dados coletados, faça uma regra de 3 para saber quual o numero que deve ser colocado em stop
stop = 1135133; start = 0


while (start <= stop):
    if serialInst.in_waiting:
        packet = serialInst.readline()
        print(packet.decode('utf').rstrip('\n'))
        list_1.append(packet)
    start += 1
# Out:
# COM5 - Arduino Uno (COM5)
#
# Selected Port:
# COM5 - Arduino Uno (COM5)
# Colecting data from COM5...
#
# Pronto vamos começar o ensaio!
# tempo total de ensaio: 35999 ms
#
#
# 1001.55        54.95        9709.89
# 905.75        -7.32        9724.26
# 920.12        59.74        9714.68
# 948.86        -2.53        9724.26
# 939.28        35.79        9757.79
# 819.53        26.21        9743.42
# 958.44        64.53        9695.52
# 896.17        -12.11        9829.64
# 939.28        -40.85        9767.37
# 991.97        78.90        9647.62
# 896.17        16.63        9781.75
# 910.54        11.84        9733.84
# 905.75        50.16        9661.99
# 814.74        11.84        9733.84
# 948.86        21.42        9690.73
# 900.96        69.32        9700.31
# 991.97        26.21        9762.58
# 1015.92        31.00        9590.14
# 872.22        31.00        9729.05
# 905.75        -2.53        9733.84
# 934.49        -16.90        9709.89
# 972.81        54.95        9781.75
# 968.02        40.58        9623.67
# 862.64        45.37        9705.10
# 915.33        21.42        9652.41
# 924.91        69.32        9623.67
# 1039.87        78.90        9781.75
# 977.60        45.37        9709.89
# 857.85        -2.53        9762.58
# 958.44        50.16        9810.48
# 982.39        54.95        9805.70
# 944.07        35.79        9714.68
# 905.75        11.84        9776.95
# 910.54        31.00        9729.05
# 991.97        102.85        9671.57
# 948.86        7.05        9719.47
# 934.49        45.37        9700.31
# 896.17        21.42        9628.46
# 862.64        2.26        9753.00
# 809.95        -21.69        9743.42
# 1030.29        45.37        9753.00
# 944.07        69.32        9719.47
# 929.70        21.42        9690.73
# 896.17        40.58        9753.00
# 1039.87        2.26        9815.27
# 1001.55        2.26        9647.62
# 805.16        40.58        9748.21
# 953.65        45.37        9767.37
# 982.39        16.63        9776.95
# 939.28        -60.01        9719.47
# 1054.24        45.37        9815.27
# 886.59        7.05        9743.42
# 872.22        2.26        9685.94
# 862.64        16.63        9762.58
# 987.18        54.95        9815.27
# 833.90        2.26        9791.32
# 1035.08        21.42        9724.26
# 977.60        21.42        9776.95
# 963.23        -16.90        9695.52
# 1063.82        21.42        9681.15
# 910.54        45.37        9609.30
# 987.18        83.69        9724.26
# 996.76        54.95        9743.42
# 963.23        -69.59        9743.42
# 900.96        7.05        9786.54
# 934.49        11.84        9719.47
# 1063.82        59.74        9776.95
# 867.43        98.06        9762.58
# 929.70        7.05        9705.10
# 944.07        26.21        9661.99
# 972.81        35.79        9657.20
# 968.02        -2.53        9633.25
# 910.54        74.11        9733.84
# 900.96        112.43        9762.58
# 948.86        -107.91        9791.32
# 929.70        64.53        9848.80
# 1030.29        54.95        9709.89
# 905.75        -7.32        9685.94
# 944.07        7.05        9738.63
# 905.75        -26.48        9738.63
# 987.18        93.27        9642.83
# 963.23        122.01        9776.95
# 953.65        -40.85        9772.16
# 924.91        -26.48        9638.04
# 862.64        2.26        9609.30
# 896.17        -12.11        9796.11
# 905.75        50.16        9800.91
# 1006.34        93.27        9700.31
# 1006.34        -31.27        9853.60
# 905.75        102.85        9805.70
# 886.59        40.58        9657.20
# 843.48        -31.27        9695.52

# %%
import pandas as pd

data = pd.DataFrame({'aa':list_1})
data
# Out:
#                                                aa
# 0    b'Pronto vamos come\xc3\xa7ar o ensaio!\r\n'
# 1          b'tempo total de ensaio: 35999 ms\r\n'
# 2                                         b'\r\n'
# 3                                         b'\r\n'
# 4      b'1001.55        54.95        9709.89\r\n'
# ..                                            ...
# 197    b'1006.34        93.27        9700.31\r\n'
# 198   b'1006.34        -31.27        9853.60\r\n'
# 199    b'905.75        102.85        9805.70\r\n'
# 200     b'886.59        40.58        9657.20\r\n'
# 201    b'843.48        -31.27        9695.52\r\n'
#
# [202 rows x 1 columns]
